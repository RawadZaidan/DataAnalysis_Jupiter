# %%
import web_scraping

df = web_scraping.return_match_df_from_web(38302,38314)

# %%
df
# Out:
#           date       home_team          away_team home_score away_score
# 0   07/10/2018        Tranmere          Liverpool          2          3  \
# 1   07/14/2018            Bury          Liverpool          0          0
# 2   07/11/2018  BSC Young Boys          Feyenoord          3          0
# 3   07/29/2018       Feyenoord            Levante          2          1
# 4   07/13/2018    Austria Wien  Borussia Dortmund          0          1
# 5   08/07/2018         Chelsea               Lyon          0          0
# 6   08/12/2018         Arsenal           Man City          0          2
# 7   08/11/2018     Bournemouth            Cardiff          2          0
# 8   08/11/2018          Fulham     Crystal Palace          0          2
# 9   08/11/2018    Huddersfield            Chelsea          0          3
# 10  08/12/2018       Liverpool           West Ham          4          0
# 11  08/10/2018         Man Utd          Leicester          2          1
#
# ...

# %%
from lookups import SEASONS
for season in SEASONS:
    print(season.value[0])
