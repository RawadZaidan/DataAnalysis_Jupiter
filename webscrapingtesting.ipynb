# %%
import web_scraping

# %%
web_scraping.return_match_df_from_web(38308,38314)
# Out:
#          date     home_team       away_team home_score away_score
# 0  08/12/2018       Arsenal        Man City          0          2  \
# 1  08/11/2018   Bournemouth         Cardiff          2          0
# 2  08/11/2018        Fulham  Crystal Palace          0          2
# 3  08/11/2018  Huddersfield         Chelsea          0          3
# 4  08/12/2018     Liverpool        West Ham          4          0
# 5  08/10/2018       Man Utd       Leicester          2          1
#
#    home_possession_%  away_possession_%  home_shots_on_target
# 0               42.0               58.0                   3.0  \
# 1               62.9               37.1                   4.0
# 2               66.3               33.7                   6.0
# 3               37.2               62.8                   1.0
# 4               64.8               35.2                   8.0
# 5               46.3               53.7                   6.0
#
# ...
